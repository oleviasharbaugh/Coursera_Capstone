# %% [markdown]
# <font size="5">**Battle of the Neighborhoods: Week 1**</font>

# %% [markdown]
# **A description of the problem and a discussion of the background:**

# %% [markdown]
#     Baton Rouge is one of the most culturally diverse cities in the United States. It has influences from France, Spain, and even local ethnic groups. It is an up and coming financial powerhouse with many new business oppourtunities developing every day. This port city has made a name for itself and is slowly transforming into what can only be called a global hub of business and commerce.
#     Though these are all great aspects of the city, they can also pose issues for those who are trying to enter into the restaurant market in Baton Rouge. Due to this difficulty, it is of utmost importance that all new businesses analyse the environment in which they are entering carefully. This analysis should help to mitigate risk and increase return in the long run.

# %% [markdown]
# **A description of the data and how it will be used to solve the problem:**

# %% [markdown]
#     Baton Rouge, and Lousisiana as a whole, is known for its cajun cuisine and it is a big part of their culture as a whole. Food tourism is a very large industry in this state. Keeping this is mind, it becomes clear that entering into this competitve market in Louisiana will not be easy, and further analysis should take place.
#
# For example, one must consider:
# 1. The population breakdown of Baton Rouge
# 2. The presence of any Farmers Markets or anything of the like nearby to obtain ingredients
# 3. The presence of population drawing
# venues: Bars, Movie Theatres, Parks
# 4. The presence and identity of competitors in that location as well as their cuisine
# 5. The presence of any untapped or saturated markets
#
#     This analysis will use data on Baton Rouge and its many neighborhoods to determine the best location to open a brand new restaurant. This data includes the name of the neighborhood, the community in which it resides, the population of people in each neighborhood, and the latitude and longitude coordinates of the neighborhood. The use of Foursquare data will also help to determine other venues in Baton Rouge, details about them, and their location. The use of these two datasets should provide adequate information to determine the best place to open a new cajun restaurant. A preview of the dataset of the 58 neighborhoods located in Baton Rouge is shown below:

# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_477046808e4d419cbfad9c17b7417ea6 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='wPOR7RSCQslmA7bHqtueJGq2-cNyAsiMQM8KWW3XVOwg',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

body = client_477046808e4d419cbfad9c17b7417ea6.get_object(Bucket='capstoneproject-donotdelete-pr-feibjkxuow1s2x',Key='Neighborhood.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

neighborhoods = pd.read_csv(body)
neighborhoods.head()
# Out:
#    ID       Neighborhood  Community  Population  Lattitude    Longitude
# 0  35           MID CITY   MID CITY        8647  30.436896   -91.122524
# 1  36       SOUTH CAMPUS  SOUTHWEST       15957  30.367287   -91.207432
# 2  37      SOUTH BURBANK  SOUTHWEST       13205  30.361173    -91.14829
# 3  38           GOODWOOD   MID CITY        5078  30.444549    -91.11095
# 4  39  NORTH BATON ROUGE      NORTH       13947  30.478934   -91.134331
